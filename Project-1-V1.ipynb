# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sat_2019 = pd.read_csv('./data/sat_2019.csv')
sat_2019
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 7%   583   560   1143
# 1                 Alaska                41%   556   541   1097
# 2                Arizona                31%   569   565   1134
# 3               Arkansas                 6%   582   559   1141
# 4             California                63%   534   531   1065
# 5               Colorado               100%   518   506   1024
# 6            Connecticut               100%   529   516   1046
# 7               Delaware               100%   499   486    985
# 8   District of Columbia                94%   495   480    975
# 9                Florida               100%   516   483    999
# 10               Georgia                71%   538   519   1058
# 11                Hawaii                54%   550   550   1100
# 12                 Idaho               100%   505   488    993
# 13              Illinois               100%   509   504   1013
# ...

# %%
act_2019 = pd.read_csv('./data/act_2019.csv')
act_2019
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       18.9
# 1                 Alaska           38%       20.1
# 2                Arizona           73%       19.0
# 3               Arkansas          100%       19.3
# 4             California           23%       22.6
# 5               Colorado           27%       23.8
# 6            Connecticut           22%       25.5
# 7               Delaware           13%       24.1
# 8   District of Columbia           32%       23.5
# 9                Florida           54%       20.1
# 10               Georgia           49%       21.4
# 11                Hawaii           80%       19.0
# 12                 Idaho           31%       22.5
# 13              Illinois           35%       24.3
# 14               Indiana           29%       22.5
# 15                  Iowa           66%       21.6
# 16                Kansas           72%       21.2
# 17              Kentucky          100%       19.8
# ...

# %%
sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
act_2019.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat_2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
act_2019.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
sat_2019.plot(kind='bar')
plt.title("SAT 2019 EBR MATH TOTAL PER STATE")
plt.xlim(xmin=0);

# %%
act_2019.plot(kind='bar')
plt.title("ACT 2019 COMPOSITE PER STATE")
plt.xlim(xmin=0);

# %%
act_2019['SAT_Composite'] = act_2019['Composite'] * 1600/36
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       18.9
# 1                 Alaska           38%       20.1
# 2                Arizona           73%       19.0
# 3               Arkansas          100%       19.3
# 4             California           23%       22.6
# 5               Colorado           27%       23.8
# 6            Connecticut           22%       25.5
# 7               Delaware           13%       24.1
# 8   District of Columbia           32%       23.5
# 9                Florida           54%       20.1
# 10               Georgia           49%       21.4
# 11                Hawaii           80%       19.0
# 12                 Idaho           31%       22.5
# 13              Illinois           35%       24.3
# 14               Indiana           29%       22.5
# 15                  Iowa           66%       21.6
# 16                Kansas           72%       21.2
# 17              Kentucky          100%       19.8
# ...

# %%
act_2019['SAT_Composite'] = act_2019['Composite'] * 1600/36
act_2019
# Out:
#                    State Participation  Composite  SAT_Composite
# 0                Alabama          100%       18.9     840.000000
# 1                 Alaska           38%       20.1     893.333333
# 2                Arizona           73%       19.0     844.444444
# 3               Arkansas          100%       19.3     857.777778
# 4             California           23%       22.6    1004.444444
# 5               Colorado           27%       23.8    1057.777778
# 6            Connecticut           22%       25.5    1133.333333
# 7               Delaware           13%       24.1    1071.111111
# 8   District of Columbia           32%       23.5    1044.444444
# 9                Florida           54%       20.1     893.333333
# 10               Georgia           49%       21.4     951.111111
# 11                Hawaii           80%       19.0     844.444444
# 12                 Idaho           31%       22.5    1000.000000
# ...

# %%
act_2019.drop(columns=['Composite'])
# Out:
#                    State Participation  SAT_Composite
# 0                Alabama          100%     840.000000
# 1                 Alaska           38%     893.333333
# 2                Arizona           73%     844.444444
# 3               Arkansas          100%     857.777778
# 4             California           23%    1004.444444
# 5               Colorado           27%    1057.777778
# 6            Connecticut           22%    1133.333333
# 7               Delaware           13%    1071.111111
# 8   District of Columbia           32%    1044.444444
# 9                Florida           54%     893.333333
# 10               Georgia           49%     951.111111
# 11                Hawaii           80%     844.444444
# 12                 Idaho           31%    1000.000000
# 13              Illinois           35%    1080.000000
# 14               Indiana           29%    1000.000000
# 15                  Iowa           66%     960.000000
# ...

# %%
sat_2019
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 7%   583   560   1143
# 1                 Alaska                41%   556   541   1097
# 2                Arizona                31%   569   565   1134
# 3               Arkansas                 6%   582   559   1141
# 4             California                63%   534   531   1065
# 5               Colorado               100%   518   506   1024
# 6            Connecticut               100%   529   516   1046
# 7               Delaware               100%   499   486    985
# 8   District of Columbia                94%   495   480    975
# 9                Florida               100%   516   483    999
# 10               Georgia                71%   538   519   1058
# 11                Hawaii                54%   550   550   1100
# 12                 Idaho               100%   505   488    993
# 13              Illinois               100%   509   504   1013
# ...

# %%
sat_2019.drop(columns=['EBRW','Math'])
# Out:
#                    State Participation Rate  Total
# 0                Alabama                 7%   1143
# 1                 Alaska                41%   1097
# 2                Arizona                31%   1134
# 3               Arkansas                 6%   1141
# 4             California                63%   1065
# 5               Colorado               100%   1024
# 6            Connecticut               100%   1046
# 7               Delaware               100%    985
# 8   District of Columbia                94%    975
# 9                Florida               100%    999
# 10               Georgia                71%   1058
# 11                Hawaii                54%   1100
# 12                 Idaho               100%    993
# 13              Illinois               100%   1013
# 14               Indiana                66%   1080
# 15                  Iowa                 3%   1244
# 16                Kansas                 4%   1241
# ...

# %%
sat_2019.plot(kind='bar')
plt.title("SAT 2019 PARTICIPATION RATE TOTAL PER STATE")
plt.xlim(xmin=0);

# %%
act_2019.plot(kind='bar')
plt.title("ACT 2019 PARTICIPATION RATE (SAT_Composite)TOTAL PER STATE")
plt.xlim(xmin=0);

# %%
sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
act_2019.describe()
# Out:
#        Composite  SAT_Composite
# count  52.000000      52.000000
# mean   21.450000     953.333333
# std     2.175487      96.688326
# min    17.900000     795.555556
# 25%    19.800000     880.000000
# 50%    20.950000     931.111111
# 75%    23.650000    1051.111111
# max    25.500000    1133.333333

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act_2019.head()
# Out:
#         State Participation  Composite  SAT_Composite
# 0     Alabama          100%       18.9     840.000000
# 1      Alaska           38%       20.1     893.333333
# 2     Arizona           73%       19.0     844.444444
# 3    Arkansas          100%       19.3     857.777778
# 4  California           23%       22.6    1004.444444

# %%
def cleaning_function(string):
    conv_string = float(string.strip('%'))/100
    return conv_string

# %%
act_2019['Participation'].apply(cleaning_function)
# Out:
# 0     1.00
# 1     0.38
# 2     0.73
# 3     1.00
# 4     0.23
# 5     0.27
# 6     0.22
# 7     0.13
# 8     0.32
# 9     0.54
# 10    0.49
# 11    0.80
# 12    0.31
# 13    0.35
# 14    0.29
# 15    0.66
# 16    0.72
# 17    1.00
# 18    1.00
# 19    0.06
# 20    0.28
# 21    0.21
# 22    0.19
# 23    0.95
# 24    1.00
# 25    0.82
# 26    1.00
# 27    1.00
# 28    1.00
# 29    0.14
# 30    0.25
# 31    0.63
# 32    0.22
# 33    1.00
# 34    0.96
# 35    1.00
# 36    1.00
# 37    0.42
# 38    0.17
# 39    0.12
# 40    0.78
# 41    0.75
# 42    1.00
# 43    0.39
# 44    1.00
# 45    0.20
# 46    0.21
# 47    0.24
# 48    0.49
# 49    1.00
# 50    1.00
# 51    0.52
# Name: Participation, dtype: float64

# %%
def setup_data(year):
    numeric_year = year
    string_year = str(year)

# Code:
# 1 - Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

sat_2019 = pd.read_csv('./sat_2019.csv')
sat_2019.head()

# 1 - Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

act_2019 = pd.read_csv('./act_2019.csv')
act_2019.head()

# 2 - Check for missing values.
sat_2019.isnull()

# 2 - Check for missing values.
act_2019.isnull()

# 6 - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1
act_2019['Participation'].apply(cleaning_function)

act_2019.head()

# 7 - Rename Columns.
act_2019.rename(columns = {'State':'state', 'Participation':'participation','Composite':'composite'}, inplace=True)
act_2019

# 6 - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1
act_2019['participation'].apply(cleaning_function)

act_2019.head()

sat_2019.head()

# 7 - Rename Columns.
sat_2019.rename(columns = {'Participation Rate':'participation','EBRW':'erbw', 'Math':'math', 'Total':'total'}, inplace=True)
sat_2019

# 8 - Drop unnecessary columns (if needed).
sat_2019.drop(columns=['erbw','math'], inplace=True)
sat_2019

sat_2019.drop(sat_2019.index[[39,47]], inplace=True)

sat_2019

sat_2019['participation'] = sat_2019['participation'].apply(cleaning_function)
sat_2019

# Converting ACT score scale into SAT for uniformity and comparision.
act_2019['sat_composite'] = act_2019['composite'] * 1600/36
act_2019

# 8 - Drop unnecessary columns (if needed).
act_2019.drop(columns=['composite'], inplace=True)
act_2019

act_2019['participation'] = act_2019['participation'].apply(cleaning_function)

act_2019

# 11- Save your cleaned and merged dataframes as csv files.
sat_2019.to_csv('./c_sat_2019.csv')

# 11- Save your cleaned and merged dataframes as csv files.
sat_2019.to_csv('./c_sat_2019.csv')

# %%
def setup_data(year):
    numeric_year = year
    string_year = str(year)
    sat_numeric_year = 'sat_' + str(numeric_year) 
    act_numeric_year = 'act_' + str(numeric_year) 

    # Code:
    # 1 - Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

    sat_numeric_year = pd.read_csv('./sat_' + string_year + '.csv')
    sat_numeric_year.head()

    # 1 - Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

    act_numeric_year = pd.read_csv('./act_' + string_year + '.csv')
    act_numeric_year.head()

    # 2 - Check for missing values.
    sat_numeric_year.isnull()

    # 2 - Check for missing values.
    act_numeric_year.isnull()

    # 6 - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1
    act_numeric_year['Participation'].apply(cleaning_function)

    act_numeric_year.head()

    # 7 - Rename Columns.
    act_numeric_year.rename(columns = {'State':'state', 'Participation':'participation','Composite':'composite'}, inplace=True)
    act_numeric_year

    # 6 - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1
    act_numeric_year['participation'].apply(cleaning_function)

    act_numeric_year.head()

    sat_numeric_year.head()

    # 7 - Rename Columns.
    sat_numeric_year.rename(columns = {'Participation Rate':'participation','EBRW':'erbw', 'Math':'math', 'Total':'total'}, inplace=True)
    sat_numeric_year

    # 8 - Drop unnecessary columns (if needed).
    sat_numeric_year.drop(columns=['erbw','math'], inplace=True)
    sat_numeric_year

    sat_numeric_year.drop(sat_numeric_year.index[[39,47]], inplace=True)

    sat_numeric_year

    sat_numeric_year['participation'] = sat_numeric_year['participation'].apply(cleaning_function)
    sat_numeric_year

    # Converting ACT score scale into SAT for uniformity and comparision.
    act_numeric_year['sat_composite'] = act_numeric_year['composite'] * 1600/36
    act_numeric_year

    # 8 - Drop unnecessary columns (if needed).
    act_numeric_year.drop(columns=['composite'], inplace=True)
    act_numeric_year

    act_numeric_year['participation'] = act_numeric_year['participation'].apply(cleaning_function)

    act_numeric_year

    # 11- Save your cleaned and merged dataframes as csv files.
    sat_numeric_year.to_csv('./c_sat_string_year.csv')

    # 11- Save your cleaned and merged dataframes as csv files.
    act_numeric_year.to_csv('./c_act_string_year.csv')
